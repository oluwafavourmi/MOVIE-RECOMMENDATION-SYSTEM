# %% [markdown]
# ### IMPORTING ALL THE REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### DATA COLLECTION AND PRE-PROCESSING

# %%
#reading the dataset
df = pd.read_csv('netflix.csv')
df.head(6)
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
# 5  Pining for his high school crush for years, a ...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
# 5                Rako Prijanto
#
#                                            Genres  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
# 3                                     TV Comedies
# 4             Documentaries, International Movies
# 5   Dramas, International Movies, Romantic Movies
#
#                                                 Cast Production Country  \
# 0                                                NaN      United States
# 1                           Yoo Ah-in, Park Shin-hye        South Korea
# 2                        Helen Mirren, Gengher Gatti              Italy
# 3  Kenya Barris, Rashida Jones, Iman Benson, Genn...      United States
# 4                                                NaN             Canada
# 5  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...          Indonesia
#
#    Release Date Rating  Duration Imdb Score Content Type         Date Added
# 0        2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 1        2020.0  TV-MA    99 min     6.2/10        Movie  September 8, 2020
# 2        2019.0  TV-14    95 min     6.4/10        Movie       July 1, 2020
# 3        2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 4        2020.0  TV-14    90 min     5.1/10        Movie   February 5, 2020
# 5        2018.0   TV-G   102 min     7.0/10        Movie       May 21, 2020

# %%
#create an index
df = df.reset_index()

# %%
df
# Out:
#       index                               Show Id  \
# 0         0  cc1b6ed9-cf9e-4057-8303-34577fb54477
# 1         1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2         2  b01b73b7-81f6-47a7-86d8-acb63080d525
# 3         3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c
# 4         4  7f2d4170-bab8-4d75-adc2-197f7124c070
# ...     ...                                   ...
# 5962   5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5963   5963  5bed77ab-5e31-4216-8b51-44c9a35442e6
# 5964   5964  4661ec0c-8692-4661-bc76-a96412b311fd
# 5965   5965  145c93a7-1924-403c-a933-4ede8ad66f26
# 5966   5966  d4613d34-cb71-4bd6-b570-fa857f02c44d
#
#                               Title  \
# 0                          (Un)Well
# 1                            #Alive
# 2     #AnneFrank - Parallel Stories
# 3                          #blackAF
# 4                  #cats_the_mewvie
# ...                             ...
# 5962                      الف مبروك
# 5963                   دفعة القاهرة
# 5964                           海的儿子
# 5965                        반드시 잡는다
# 5966            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# 0     This docuseries takes a deep dive into the luc...
# 1     As a grisly virus rampages a city, a lone man ...
# 2     Through her diary, Anne Frank's story is retol...
# 3     Kenya Barris and his family navigate relations...
# 4     This pawesome documentary explores how our fel...
# ...                                                 ...
# 5962  On his wedding day, an arrogant, greedy accoun...
# 5963  A group of women leaves Kuwait to attend unive...
# 5964  Two brothers start a new life in Singapore, wh...
# 5965  After people in his town start turning up dead...
# 5966  Miniforce, a special task force of elite range...
#
#                          Director  \
# 0                             NaN
# 1                          Cho Il
# 2     Sabina Fedeli, Anna Migotto
# 3                             NaN
# 4                Michael Margolis
# ...                           ...
# 5962            Ahmed Nader Galal
# 5963                          NaN
# 5964                          NaN
# 5965                Hong-seon Kim
# 5966                Young Jun Lee
#
#                                               Genres  \
# 0                                         Reality TV
# 1     Horror Movies, International Movies, Thrillers
# 2                Documentaries, International Movies
# 3                                        TV Comedies
# 4                Documentaries, International Movies
# ...                                              ...
# 5962          Comedies, Dramas, International Movies
# 5963               International TV Shows, TV Dramas
# 5964               International TV Shows, TV Dramas
# 5965         Dramas, International Movies, Thrillers
# 5966                        Children & Family Movies
#
#                                                    Cast Production Country  \
# 0                                                   NaN      United States
# 1                              Yoo Ah-in, Park Shin-hye        South Korea
# 2                           Helen Mirren, Gengher Gatti              Italy
# 3     Kenya Barris, Rashida Jones, Iman Benson, Genn...      United States
# 4                                                   NaN             Canada
# ...                                                 ...                ...
# 5962  Ahmed Helmy, Laila Ezz El Arab, Mahmoud El Fis...              Egypt
# 5963  Bashar al-Shatti, Fatima Al Safi, Maram Baloch...                NaN
# 5964  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...                NaN
# 5965                                      Baek Yoon-sik        South Korea
# 5966  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...                NaN
#
#       Release Date Rating  Duration Imdb Score Content Type         Date Added
# 0           2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 1           2020.0  TV-MA    99 min     6.2/10        Movie  September 8, 2020
# 2           2019.0  TV-14    95 min     6.4/10        Movie       July 1, 2020
# 3           2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 4           2020.0  TV-14    90 min     5.1/10        Movie   February 5, 2020
# ...            ...    ...       ...        ...          ...                ...
# 5962        2009.0  TV-14   115 min     7.4/10        Movie     April 25, 2020
# 5963        2019.0  TV-14  1 Season        NaN      TV Show                NaN
# 5964        2016.0  TV-14  1 Season        NaN      TV Show                NaN
# 5965        2017.0  TV-MA   110 min     6.5/10        Movie  February 28, 2018
# 5966        2018.0  TV-Y7    68 min     4.7/10        Movie  September 1, 2018
#
# [5967 rows x 14 columns]

# %%
df.shape
# Out:
# (5967, 14)

# %%
#select certain features
selcted_features = ['Title', 'Description', 'Director', 'Genres', 'Content Type']
print(selcted_features)
# Out:
# ['Title', 'Description', 'Director', 'Genres', 'Content Type']

# %%
#clean the data and fill null values
for feature in selcted_features:
    df[feature] = df[feature].fillna('')

# %%
df['Title'] = df['Title'].str.replace('#', '')

# %%
cleaned_title = df['Title']

# %%
#put all the features into one
combined_features = cleaned_title+ ''+ df['Description']+''+ df['Director']+''+ df['Genres']+ ''+ df['Content Type']

# %%
combined_features
# Out:
# 0       (Un)WellThis docuseries takes a deep dive into...
# 1       AliveAs a grisly virus rampages a city, a lone...
# 2       AnneFrank - Parallel StoriesThrough her diary,...
# 3       blackAFKenya Barris and his family navigate re...
# 4       cats_the_mewvieThis pawesome documentary explo...
#                               ...
# 5962    الف مبروكOn his wedding day, an arrogant, gree...
# 5963    دفعة القاهرةA group of women leaves Kuwait to ...
# 5964    海的儿子Two brothers start a new life in Singapore...
# 5965    반드시 잡는다After people in his town start turning ...
# 5966    최강전사 미니특공대 : 영웅의 탄생Miniforce, a special task f...
# Length: 5967, dtype: object

# %%
#change all the text data into vectors
vectorizer = TfidfVectorizer()

# %%
featured_vectors = vectorizer.fit_transform(combined_features)

# %%
print(featured_vectors)
# Out:
#   (0, 21831)	0.0649216292474742
#   (0, 24890)	0.12153660451556257
#   (0, 19549)	0.13732989809570623
#   (0, 18913)	0.26915800084143526
#   (0, 24346)	0.05136836233621543
#   (0, 25286)	0.09782901934894675
#   (0, 14096)	0.16208106046321036
#   (0, 18868)	0.27847830864373213
#   (0, 6964)	0.1798420398323072
#   (0, 3736)	0.1097016656555808
#   (0, 10717)	0.22633582856240458
#   (0, 1277)	0.04934637678947077
#   (0, 10718)	0.23097200174529553
#   (0, 24513)	0.2916145446922719
#   (0, 26209)	0.19147112299853603
#   (0, 11784)	0.22228080000990497
#   (0, 26148)	0.2619286084617809
#   (0, 14378)	0.23097200174529553
#   (0, 24077)	0.13598564186602324
#   (0, 12034)	0.11391839832640618
#   (0, 6931)	0.24670145699059862
#   (0, 6264)	0.1922159361328916
#   (0, 23698)	0.1439082257897301
#   (0, 6984)	0.14749175826353456
#   (0, 26154)	0.2916145446922719
#   :	:
#   (5966, 23834)	0.23155379261943954
#   (5966, 12705)	0.2279721653823745
#   (5966, 13646)	0.1826129020114238
#   (5966, 18721)	0.2356143066838119
#   (5966, 24426)	0.18417266364630988
#   (5966, 9011)	0.17770894970044432
#   (5966, 22608)	0.13755925613822179
#   (5966, 7628)	0.17292914279463276
#   (5966, 12209)	0.12421021437696149
#   (5966, 1633)	0.17706874321064034
#   (5966, 21035)	0.1414229495474257
#   (5966, 7413)	0.1604157431807026
#   (5966, 17198)	0.08080011905157818
#   (5966, 2562)	0.15444712924232587
#   (5966, 26790)	0.10801559445473317
#   (5966, 24888)	0.06748888235390069
#   (5966, 21460)	0.1116217547185934
#   (5966, 8404)	0.09102645356419553
#   (5966, 16101)	0.061102700850280835
#   (5966, 24146)	0.09480508361471808
#   (5966, 11696)	0.05833819236116402
#   (5966, 17073)	0.051151936212392494
#   (5966, 24346)	0.09642860860812458
#   (5966, 24077)	0.08509067734465921
#   (5966, 23698)	0.1350721470283676

# %%
print(featured_vectors.shape)
# Out:
# (5967, 27052)

# %%
similarity = cosine_similarity(featured_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.00474379 0.         ... 0.0349747  0.00874619 0.03596248]
#  [0.00474379 1.         0.00947082 ... 0.0034465  0.05245561 0.00463123]
#  [0.         0.00947082 1.         ... 0.01050651 0.01980926 0.01633836]
#  ...
#  [0.0349747  0.0034465  0.01050651 ... 1.         0.0656108  0.02922997]
#  [0.00874619 0.05245561 0.01980926 ... 0.0656108  1.         0.00331367]
#  [0.03596248 0.00463123 0.01633836 ... 0.02922997 0.00331367 1.        ]]

# %%
print(similarity.shape)
# Out:
# (5967, 5967)

# %%
movie_name = input('enter a movie name')

# %%
list_of_titles = cleaned_title.to_list()

# %%
print(list_of_titles)
# Out:
# ['(Un)Well', 'Alive', 'AnneFrank - Parallel Stories', 'blackAF', 'cats_the_mewvie', 'FriendButMarried', 'FriendButMarried 2', 'realityhigh', 'Rucker50', 'Selfie', 'Selfie 69', '10 Days in Sun City', '10 jours en or', '100 Days My Prince', '100 Humans', '100 Meters', '100 Things to do Before High School', '100% Halal', '1000 Rupee Note', '122', '13 Reasons Why', '13 Reasons Why: Beyond the Reasons', '13TH', '14 Minutes from Earth', '15 August', '18 Presents', '1898: Our Last Men in the Philippines', '1922', '1983', '1994', '1BR', '2 Hearts', '2 States', '2 Weeks in Lagos', '2,215', '20 Minutes', '2012', '21 Again', '21 Thunder', '22 July', '23:59', '25 Kille', '26 Years', '28 Moons', '3 Days to Kill', '3 Generations', '3 Idiots', '3 Türken & ein Baby', '3%', '3022', '365 Days', '37 Seconds', '3Below: Tales of Arcadia', '40 Sticks', '44 Cats', '45 rpm', '46', '48 Christmas Wishes', '4L', '4th Republic', '5 Flights Up', '5 Star Christmas', '50M2', '5Gang', '6 Balloons', '6 Bullets', '6 Underground', '6 Years', '60 Days In', '678', '7 años', '7 Days Out', '7 Khoon Maaf', '7 Yards: The Chris Norton Story', '7:19', '72 Cutest Animals', '72 Dangerous Animals: Asia', '72 Dangerous Animals: Latin America', '72 Dangerous Places to Live', '7SEEDS', '90 ML', '93 Days', '99 Songs', '99 Songs (Tamil)', '99 Songs (Telugu)', 'A 2nd Chance', 'A 3 Minute Hug', "A Babysitter's Guide to Monster Hunting", 'A Beautiful Life', 'A Boy Name Flora A', 'A California Christmas', 'A Chaster Marriage', 'A Choo', 'A Christmas Catch', 'A Christmas Prince', 'A Christmas Prince: The Royal Baby', 'A Christmas Prince: The Royal Wedding', 'A Christmas Special: Miraculous: Tales of Ladybug & Cat Noir', 'A Cinderella Story: Christmas Wish', 'A Classic Horror Story', 'A Clockwork Orange', 'A Fairly Odd Summer', 'A Fall from Grace', 'A Family', 'A Family Reunion Christmas', 'A Fortunate Man', 'A Futile and Stupid Gesture', 'A Ghost Story', 'A Go! Go! Cory Carson Christmas', 'A Go! Go! Cory Carson Halloween', 'A Go! Go! Cory Carson Summer Camp', 'A Grand Night In: The Story of Aardman', 'A Haunted House 2', 'A Heavy Heart', 'A Home with A View', 'A House of Blocks', 'A Kid from Coney Island', 'A Korean Odyssey', 'A Land Imagined', 'A Life of Speed: The Juan Manuel Fangio Story', 'A Lion in the House', 'A Little Chaos', 'A Little Help with Carol Burnett', 'A Little Thing Called First Love', 'A Love So Beautiful', 'A Love So Beautiful', 'A Love Song for Latasha', 'A Love Story', 'A Man For The Week End', 'A Mighty Team', 'A Monster Calls', 'A New York Christmas Wedding', 'A Noble Intention', 'A Perfect Crime', 'A Perfect Day For Arsenide', 'A Perfect Ending', 'A Perfect Fit', 'A Place in the Stars', 'A Plastic Ocean', 'A Princess for Christmas', 'A Private War', 'A Queen Is Born', 'A Remarkable Tale', 'A Second Chance', 'A Secret Love', 'A Series of Unfortunate Events', 'A Shaun the Sheep Movie: Farmageddon', 'A Silent Voice', 'A Single Man', 'A Sort of Family', 'A Stoning in Fulham County', 'A StoryBots Christmas', 'A Sun', 'A Taiwanese Tale of Two Cities', 'A Tale of Two Kitchens', 'A Thousand Goodnights', 'A Touch of Green', 'A Trash Truck Christmas', 'A Trip to Jamaica', 'A truthful Mother', 'A Twelve Year Night', 'A Very Country Christmas', 'A Very Murray Christmas', 'A Very Secret Service', 'A Very Special Love', 'A Way Back Home', 'A Week Away', 'A Whisker Away', "A Witches' Ball", 'A Year In Space', 'A Yellow Bird', 'A.I.C.O.', 'Aagey Se Right', 'Aakhri Adaalat', 'Aalorukkam', 'Aamir', 'Aapla Manus', 'Aashik Awara', 'Aaviri', 'Abby Hatcher', 'ABCD 2', 'ABCD: Any Body Can Dance', 'Abducted in Plain Sight', 'Abduction', 'Abdullah, The Final Witness', 'Abla Fahita: Drama Queen', 'About Time', 'Abstract: The Art of Design', 'Absurd Planet', 'Abyss', 'Abzurdah', 'Accepted', 'Accident', 'Accidentally in Love', 'Accomplice', 'Across Grace Alley', 'Action Replayy', 'Acts of Vengeance', 'Ad Vitam', 'Adam Devine: Best Time of Our Lives', 'ADAM SANDLER 100% FRESH', 'Adam:  ...

# %%
#find close match of our input to our dataset
find_close_match = difflib.get_close_matches(movie_name, list_of_titles)
print(find_close_match)
# Out:
# ['Skin', 'Smoking', 'Skins']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Skin

# %%
#finding the index of the movie
index_of_the_movie = df[cleaned_title == close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 4291

# %%
#getting a list of similar movies
similarity_score = list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, 0.007763021069415175), (1, 0.028116021023515306), (2, 0.018022929795080522), (3, 0.011355962174227317), (4, 0.05108314679282629), (5, 0.016314627609970753), (6, 0.017456236346273107), (7, 0.01738144323276561), (8, 0.011907067247708337), (9, 0.01817147376234442), (10, 0.015794115019096458), (11, 0.0822877454380672), (12, 0.024556859930334584), (13, 0.010828897385710894), (14, 0.008984221535966152), (15, 0.010809226285129103), (16, 0.020739691879757584), (17,
579372205146515), (1414, 0.06568227348821086), (2996, 0.06568115296287258), (923, 0.06551474021617172), (5928, 0.06543582482774257), (583, 0.06509079952840763), (3036, 0.06494504092433946), (2096, 0.06476793115698962), (467, 0.06476331576781591), (1785, 0.06466457973337184), (1840, 0.06460164476644448), (4271, 0.06454823843049784), (2927, 0.06440656009726646), (2231, 0.06440310086090631), (2913, 0.06435351357714998), (4913, 0.06423546644923397), (5144, 0.0641741377010846), (2134, 0.06407505179085854), (1294, 0.0631710382475828), (196, 0.06314857724038724), (2086, 0.06303595408579175), (4850, 0.0629815630948139), (4456, 0.06283509266859083), (137, 0.06274490843804385), (1473, 0.06247078292476047), (3194, 0.062412184393884726), (1667, 0.06229527063525293), (3048, 0.06226735144625131), (4086, 0.06186312916186997), (4873, 0.06181511568165406), (1866, 0.06177661306747074), (3459, 0.06176390043216276), (489, 0.061722751447392234), (708, 0.0616226882272754), (1118, 0.061564777392194577), (5888, 0.06153385732401682), (4527, 0.06124338341959225), (5065, 0.061099736330621025), (2981, 0.06107946039912554), (1051, 0.06105986627623999), (2105, 0.06101556622191581), (490, 0.06080837976606077), (2842, 0.060801292980982455), (492, 0.060674028420943285), (4020, 0.06054724255195644), (2816, 0.06036763931242046), (5220, 0.060324555456298196), (869, 0.06030792122719814), (4482, 0.05994009758259976), (5262, 0.05976615889406201), (1663, 0.05963066098014518), (4697, 0.05962224962828047), (1710, 0 ...

# %%
#print the name of familiar movies based on the index
print('Movies suggested for you : \n')
i = 1
for movie in sorted_similar_movie:
    index = movie[0]
    title_from_index = df[df.index==index]['Title'].values[0]
    if (i<30):
        print(i, ',', title_from_index)
        i+=1
# Out:
# Movies suggested for you :
#
# 1 , Skin
# 2 , Beverly Hills Ninja
# 3 , Marked
# 4 , 2 Weeks in Lagos
# 5 , Miss Virginia
# 6 , Daniel Sloss: Live Shows
# 7 , All American
# 8 , Eggnoid: Love & Time Portal
# 9 , Thi Mai
# 10 , Citation
# 11 , Born Racer
# 12 , Under the Eiffel Tower
# 13 , Michael Lost and Found
# 14 , The Social Dilemma
# 15 , Sleepless Society: Nyctophobia
# 16 , Country Comfort
# 17 , Flavors of Youth: International Version
# 18 , An Evening with Beverly Luff Linn
# 19 , Autumn's Concerto
# 20 , The Tenth Man
# 21 , Iron Ladies
# 22 , A Very Country Christmas
# 23 , 10 Days in Sun City
# 24 , LEGO Bionicle: The Journey to One
# 25 , The Power of Grayskull: The Definitive History of He-Man and the Masters of the Universe
# 26 , The Strange House
# 27 , Garth Brooks: The Road I’m On
# 28 , Seven and a half dates
# 29 , Seventeen

# %% [markdown]
# ### MOVIE RECOMMENDATION SYSTEM

# %%
movie_name = input('enter a movie name')

list_of_titles = cleaned_title.to_list()

find_close_match = difflib.get_close_matches(movie_name, list_of_titles)

close_match = find_close_match[0]

index_of_the_movie = df[cleaned_title == close_match]['index'].values[0]

similarity_score = list(enumerate(similarity[index_of_the_movie]))

sorted_similar_movie = sorted(similarity_score, key= lambda x:x[1], reverse=True)

print('Movies suggested for you : \n')
i = 1
for movie in sorted_similar_movie:
    index = movie[0]
    title_from_index = df[df.index==index]['Title'].values[0]
    if (i<30):
        print(i, ',', title_from_index)
        i+=1
